# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec

# %%
import matplotlib.animation as animation
fig, ([subplot1, subplot2], [subplot3, subplot4]) = plt.subplots(2,2)
plt.cla()
n = 100
x1 = np.random.normal(0,1,n)
x2 = np.random.gamma(2,1,n)
x3 = np.random.exponential(2,n)+7
x4 = np.random.uniform(0,6,n)
bins = 10
subplot1.hist(x1, bins = bins, alpha = 0.5, color = "red")
subplot2.hist(x2, bins = bins, alpha = 0.5, color = "green")
subplot3.hist(x3, bins = bins, alpha = 0.5, color = "blue")
subplot4.hist(x4, bins = bins, alpha = 0.5, color = "orange")
subplot1.set_title("Normal")
subplot2.set_title("Gamma")
subplot3.set_title("Exponential")
subplot4.set_title("Uniform")
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# very basic function to animate four graphs
# definig the function
fig, ([subplot1, subplot2], [subplot3, subplot4]) = plt.subplots(2,2) # 2x2 grid of subplots
n = 100  # setting a parameter for the number of frames you want
x1 = np.random.normal(0,1,n)
x2 = np.random.gamma(2,1,n)
x3 = np.random.exponential(2,n)+7   # these will populate the subplots(can be any variables you want)
x4 = np.random.uniform(0,6,n)
#y = np.random.normal(loc=0.0, scale=1.0, size=1000)   you'll need a y value for any graphs not histograms
def update(curr):
    if curr == n:
        a.event_source.stop()   # creates a loop that will stop when the number of frames reaches n
    subplot1.cla()   #↓
    subplot2.cla()
    subplot3.cla()
    subplot4.cla()   #↑ clears subplots for population of data
    
    #x1 = np.random.normal(0,1,n)
    #x2 = np.random.gamma(2,1,n)
    #x3 = np.random.exponential(2,n)+7
    #x4 = np.random.uniform(0,6,n)
    
    bins = 1 + curr  # sets bin number for the histograms to the present value
    subplot1.hist(x1, bins = bins, alpha = 0.5, color = "red")   # creates the graphs(can be any graph you want)
    subplot2.hist(x2, bins = bins, alpha = 0.5, color = "green")
    subplot3.hist(x3, bins = bins, alpha = 0.5, color = "blue")   
    subplot4.hist(x4, bins = bins, alpha = 0.5, color = "orange")   # just make sure they're populated correctly
    subplot1.set_xticks([])   #↓ setting the graph parameters (tick-marks)
    subplot2.set_xticks([])   
    subplot3.set_xticks([])
    subplot4.set_xticks([])
    subplot1.set_yticks([])
    subplot2.set_yticks([])
    subplot3.set_yticks([])
    subplot4.set_yticks([])   #↑
    
    subplot1.set_title("Normal")
    subplot2.set_title("Gamma")
    subplot3.set_title("Exponential")
    subplot4.set_title("Uniform")
    
    fig.suptitle("Number of bins: {}".format(bins))
    plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# animationg the function
Writer = animation.writers["ffmpeg"]
writer = Writer(fps = 15, bitrate = 1000)
fig, ([subplot1, subplot2], [subplot3, subplot4]) = plt.subplots(2,2)
ani = animation.FuncAnimation(fig, update, interval = 100, frames = 100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# this is just a bullshit function to show the power

def squiggle_xy(a,b,c,d, i=np.arange(0.0,2*np.pi, 0.05)):
    return np.sin(i*a)*np.cos(i*b), np.sin(i*c)*np.cos(i*d)

fig11=plt.figure(figsize = (8,8))
outer_grid = fig11.add_gridspec(4,4, wspace=0, hspace=0)

for a in range(4):
    for b in range(4):
        inner_grid = outer_grid[a,b].subgridspec(3,3,wspace=0, hspace=0)
        axs = inner_grid.subplots()
        for (c,d), ax in np.ndenumerate(axs):
            ax.plot(*squiggle_xy(a+1,b+1,c+1,d+1))
            ax.set(xticks=[], yticks=[])
            
            
for ax in fig11.get_axes():
    ss = ax.get_subplotspec()
    ax.spines.top.set_visible(ss.is_first_row())
    ax.spines.bottom.set_visible(ss.is_last_row())
    ax.spines.left.set_visible(ss.is_first_col())
    ax.spines.right.set_visible(ss.is_last_col())
    
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
